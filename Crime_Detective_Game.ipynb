# %% [markdown]
# <a href="https://colab.research.google.com/github/Saisneha0209/ASSIGNMENT/blob/main/Crime_Detective_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Crime Detective Game
names = ['Kiara', 'Damini', 'Mehek', 'Preeti']
weapons = ['Pistol', 'Knife', 'Rifle', 'Sniper']
ages = [29, 23, 17, 15]
locations = ['Delhi', 'Mumbai', 'Chennai', 'Delhi']


def find_people(name, age):
  if name == 'Kiara' and age == 29:
        print("Person Found!")
        print("I.HER Location IS: Delhi")
        print("II.HER Weapon IS: Pistol")
  elif name == 'Damini' and age == 23:
        print("Person Found!")
        print("I.HER Location IS: Mumbai")
        print("II.HER Weapon IS: Knife")

  elif name == 'Mehek' and age == 17:
        print("Person Found!")
        print("I.HER Location IS: Chennai")
        print("II.HER Weapon IS: Rifle")

  elif name == 'Preeti' and age == 15:
        print("Person Found!")
        print("I.HER Location IS: Delhi")
        print("II.HER Weapon IS: Sniper")
  else:
     print("No agent matched check your details again! Mission Failed!")

find_people('Kiara', 29)
print("#1ST Person details has been found successfully!!")
find_people('Mehek', 17)
print("#2ND Person details has been found successfully!!")
# Out:
# Person Found!
# I.HER Location IS: Delhi
# II.HER Weapon IS: Pistol
# #1ST Person details has been found successfully!!
# Person Found!
# I.HER Location IS: Chennai
# II.HER Weapon IS: Rifle
# #2ND Person details has been found successfully!!
