# %% [markdown]
# <a href="https://colab.research.google.com/github/Saisneha0209/ASSIGNMENT/blob/main/ASSIGNMENT_1_and_2!!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#MINI SHOPPING CALCULATOR:-
product= input("Enter product name:")
price =float(input("Enter price per item:"))
quantity =int(input("Enter quantity:"))
discount_percent =float(input("Enter discount percentage: "))
total_before_discount = price * quantity
discount_amount = (discount_percent / 100) * total_before_discount
final_amount = total_before_discount - discount_amount
if_more_than_20 = discount_percent > 20
print("SHOPPING RECEIPT")
print(f"Item: {product}")
print(f"Price per item: {price}")
print(f"Quantity: {quantity}")
print(f"Total before discount: {total_before_discount}")
print(f"Discount Applied: {discount_percent}")
print(f"More than 20% discount?: {if_more_than_20}")
print(f"Final Amount to Pay: {final_amount}")
# Out:
# Enter product name:Black Shirt
# Enter price per item:480
# Enter quantity:4
# Enter discount percentage: 10
# SHOPPING RECEIPT
# Item: Black Shirt
# Price per item: 480.0
# Quantity: 4
# Total before discount: 1920.0
# Discount Applied: 10.0
# More than 20% discount?: False
# Final Amount to Pay: 1728.0

# %% [markdown]
# #Student Information Management System:-

# %%
students = [
    {"name": "Aarav",
        "age": 20,
        "courses": ("Python", "Maths", "Physics"),
        "skills": {"Python", "HTML"}
    },
    {"name": "Meha",
        "age": 19,
        "courses": ("Biology", "Python"),
        "skills": {"Python", "CSS"}
    },

    { "name": "Rohit",
        "age": 22,
        "courses": ("Chemistry", "Maths"),
        "skills": {"SQL", "Excel"}
    },

    {"name": "Ananya",
        "age": 18,
        "courses": ("History", "English"),
        "skills": {"Writing", "Communication"}
    },
    { "name": "Kunal",
        "age": 21,
        "courses": ("Python", "Computer Science"),
        "skills": {"Python", "SQL"}
    }
]
new_student = {
    "name": "Ishaan",
    "age": 20,
    "courses": ("Python", "AI"),
    "skills": {"Python", "Machine Learning"}
}
#Now we will add our new student:-
students.append(new_student)

#Now to change the age of Aarav!!
students[0]["age"] = 21

#Here we have created an empty list in which the names of students will be stores who know python!!
python_students=[]
for student in students:
    if "Python" in student["courses"]:
        python_students.append(student["name"])

#Now we will see all the skills of each student:-
all_skills = set()
for student in students:
    all_skills = all_skills.union(student["skills"])

print("!!!Student Dashboard!!!")
print(f"Total Students:{len(students)}\n")
print("Students Enrolled in Python:")
for name in python_students:
    print(name)
print("----------------------")
print("\nUnique Skills Across All Students:\n")
print(all_skills)
# Out:
# !!!Student Dashboard!!!
# Total Students:6
#
# Students Enrolled in Python:
# Aarav
# Meha
# Kunal
# Ishaan
# ----------------------
#
# Unique Skills Across All Students:
#
# {'CSS', 'HTML', 'SQL', 'Python', 'Writing', 'Excel', 'Communication', 'Machine Learning'}
